# %% [markdown]
# <a href="https://colab.research.google.com/github/dostonshernazarov/MachineLearning_models/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/reklama_sales.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.corrwith(df['Sales'])
# Out:
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Sales        1.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df[['TV', 'Sales']], test_size=0.1, random_state=42)
train_set
# Out:
#         TV  Sales
# 124  229.5   19.7
# 16    67.8   12.5
# 148   38.0   10.9
# 93   250.9   22.2
# 65    69.0   11.3
# ..     ...    ...
# 106   25.0    7.2
# 14   204.1   19.0
# 92   217.7   19.4
# 179  165.6   17.6
# 102  280.2   19.8
#
# [180 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

St_scal = StandardScaler()
X_prep = St_scal.fit_transform(train_set.drop(['Sales'], axis=1))
label_prep = St_scal.fit_transform(train_set.drop(['TV'], axis=1))

# %%
from sklearn.linear_model import  LinearRegression

LR_model = LinearRegression()
LR_model.fit(X_prep, train_set.drop(['TV'], axis=1))
# Out:
# LinearRegression()

# %%
test_data = train_set.sample(10)
test_data.drop(['Sales'], axis=1, inplace=True)

# %%
test_lable = train_set.loc[test_data.index]
test_lable.drop(['TV'], axis=1, inplace=True)
test_lable
# Out:
#      Sales
# 50    16.4
# 10    12.6
# 4     17.9
# 105   15.0
# 194   17.3
# 196   14.0
# 102   19.8
# 33    17.4
# 171   17.5
# 123   15.2

# %%
preparing_test_data = St_scal.fit_transform(test_data)

# %%
pridected_data = LR_model.predict(preparing_test_data)
pridected_data
# Out:
# array([[17.62865237],
#        [ 7.97414513],
#        [16.25665807],
#        [13.15883937],
#        [14.01092004],
#        [10.00325249],
#        [23.43435455],
#        [22.38008525],
#        [15.07963138],
#        [12.09012802]])

# %%
test_lable
# Out:
#      Sales
# 50    16.4
# 10    12.6
# 4     17.9
# 105   15.0
# 194   17.3
# 196   14.0
# 102   19.8
# 33    17.4
# 171   17.5
# 123   15.2

# %%
X_test = test_set.drop(['Sales'], axis=1)
y_test = test_set['Sales'].copy()
x_test
# Out:
# 95     163.3
# 15     195.4
# 30     292.9
# 158     11.7
# 128    220.3
# 115     75.1
# 69     216.8
# 170     50.0
# 174    222.4
# 45     175.1
# 66      31.5
# 182     56.2
# 165    234.5
# 78       5.4
# 186    139.5
# 177    170.2
# 56       7.3
# 152    197.6
# 82      75.3
# 68     237.4
# Name: TV, dtype: float64

# %%
x_test_prepared = St_scal.transform(X_test)

# %%
predicted_test_data = LR_model.predict(x_test_prepared)
predicted_test_data
# Out:
# array([[14.99297911],
#        [17.31092737],
#        [24.35142442],
#        [ 4.04590883],
#        [19.108962  ],
#        [ 8.62403717],
#        [18.85622621],
#        [ 6.81156049],
#        [19.26060348],
#        [15.84505978],
#        [ 5.47567131],
#        [ 7.25926389],
#        [20.13434721],
#        [ 3.59098441],
#        [13.27437573],
#        [15.49122967],
#        [ 3.72818384],
#        [17.46978987],
#        [ 8.63847921],
#        [20.34375687]])

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    16.5
# 45     16.1
# 66     11.0
# 182     8.7
# 165    16.9
# 78      5.3
# 186    10.3
# 177    16.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# Name: Sales, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

lin_mse = mean_squared_error(y_test, predicted_test_data)
lin_rmse = np.sqrt(lin_mse)

# %%
lin_rmse
# Out:
# 3.060389920900402

# %%
import joblib
filename = 'LR_model.jbl'
joblib.dump(LR_model, filename)
# Out:
# ['LR_model.jbl']
